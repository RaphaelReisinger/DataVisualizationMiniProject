# %% [markdown]
# # What factors influence motorcycle performance and design?
# ###### Raphael Reisinger & Julian Murach

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)


motorcycle_data = pd.read_csv('data/all_bikez_curated.csv')
motorcycle_data.sample(n=1)
# Out:
# C:\Users\Smartbar\AppData\Local\Temp\ipykernel_23160\3626600937.py:13: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   motorcycle_data = pd.read_csv('data/all_bikez_curated.csv')
#           Brand      Model  Year Category  Rating  Displacement (ccm)  \
# 18912  kawasaki  z 1000 st  1979  Classic     3.9              1015.0
#
#        Power (hp)  Torque (Nm) Engine cylinder Engine stroke  Gearbox  \
# 18912        97.0          NaN    In-line four   four-stroke  5-speed
#
#        Bore (mm) Stroke (mm)  Fuel capacity (lts) Fuel system  \
# 18912       70.0        66.0                 18.0         NaN
#
#                                Fuel control Cooling system Transmission type  \
# 18912  Double Overhead Cams/Twin Cam (DOHC)            Air       Shaft drive
#
#        Dry weight (kg)  Wheelbase (mm)  Seat height (mm) Front brakes  \
# 18912              NaN             NaN               NaN    Dual disc
#
# ...

# %% [markdown]
# 1. Power trends over time
# 2. Displacement ↔ horsepower relationships
# 3. Weight vs. performance
# 4. Differences between categories (Sport, Cruiser, Adventure…)
# 5. Seat height, wheelbase, torque, fuel capacity comparisons

# %% [markdown]
# 1. Power trends over time

# %%
sns.set_palette('Dark2')
plt.figure(figsize=(15,5))
line_plot = sns.lineplot(data=motorcycle_data, x='Year', y='Power (hp)', hue='Brand', dashes=False)
