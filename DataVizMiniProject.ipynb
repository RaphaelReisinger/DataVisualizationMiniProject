# %% [markdown]
# # What factors influence motorcycle performance and design?
# ###### Raphael Reisinger & Julian Murach

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)


motorcycle_data = pd.read_csv('data/all_bikez_curated.csv')
motorcycle_data.sample(n=1)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_22040\3626600937.py:13: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   motorcycle_data = pd.read_csv('data/all_bikez_curated.csv')
#        Brand                     Model  Year          Category  Rating  \
# 27084  rieju  mrt pro 50  competizione  2013  Enduro / offroad     NaN
#
#        Displacement (ccm)  Power (hp)  Torque (Nm)  Engine cylinder  \
# 27084                50.0         NaN          NaN  Single cylinder
#
#       Engine stroke  Gearbox  Bore (mm) Stroke (mm)  Fuel capacity (lts)  \
# 27084    two-stroke  6-speed       40.3        39.0                  6.3
#
#                   Fuel system Fuel control Cooling system Transmission type  \
# 27084  Carburettor. Dell´Orto          NaN         Liquid             Chain
#
#        Dry weight (kg)  Wheelbase (mm)  Seat height (mm)  \
# 27084             85.0          1405.0             850.0
#
#                               Front brakes                Rear brakes  \
# 27084  Single disc. 2-piston. Galfer Wave.  Single disc. Galfer Wave.
#
#       Front tire   Rear tire                   Front suspension  \
# 27084  80/90-21   110/80-18   Marzocchi inverted fork of Ø40mm.
#
#                                                     Rear suspension  \
# 27084  Gas Mono-shock shock absorber and separate bottle PRS system
#
#       Color options
# 27084  Green/yellow

# %% [markdown]
# 1. Power trends over time
# 2. Displacement ↔ horsepower relationships
# 3. Weight vs. performance
# 4. Differences between categories (Sport, Cruiser, Adventure…)
# 5. Seat height, wheelbase, torque, fuel capacity comparisons

# %% [markdown]
# 1. Power trends over time

# %%
sns.set_palette('Dark2')
plt.figure(figsize=(15,5))
line_plot = sns.lineplot(data=motorcycle_data, x='Year', y='Power (hp)', hue='Brand', dashes=False)
